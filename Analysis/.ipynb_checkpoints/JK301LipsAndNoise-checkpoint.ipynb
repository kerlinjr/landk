# %% [markdown]
# # JK301 Visual Impact on Phoneme Perception in Noise with Natural Sentences
#
# We are going to look at the pilot data and try to attack a few key questions with this notebook.
#
# 1. How much does lip reading improve phonemic perception of clear vs noisy speech?
#
# 2. Does this interaction change over the course of a sentence?
#
# 3. Do some phonemes benefit from speechreading more than others?

# %% [markdown]
# ### Loading...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame.from_csv('C:\\TCDTIMIT\\dataOut\\JK301\\bigPJK301_r1.csv')

#Relabel babble condition for clarity
df.loc[df['BabbleCond'] == 'Off',('BabbleCond')] = 'Clear'
df.loc[df['BabbleCond'] == 'On',('BabbleCond')] = 'Noisy'
df.loc[df['VideoCond'] == 'Normal',('VideoCond')] = 'Audiovisual'
df.loc[df['VideoCond'] == 'Static',('VideoCond')] = 'Auditory Only'

#Make WordIdx start from 1, not zero
df.WordIdx = df.WordIdx+1

# %% [markdown]
# Lessons learned from Jk301 Initial Notes

# %%
# Fix phoneme alignment issue (correct word given but phonemes assigned to wrong word)
# Find where words match
matchIdx = df['SourceWord'] == df['TargetWord']
#Set the source phonemes to match the target
df.loc[matchIdx,('SourcePhoneme')] = df.loc[matchIdx,('TargetPhoneme')] 
#Reset the measure of phoneme accuracy
df.loc[:,'PhonemeHitBool'] = df['SourcePhoneme'] == df['TargetPhoneme']
#Set a measure all phonemes matching
df.loc[:,('AllPhonsMatch')] = df.groupby('WordCount')['PhonemeHitBool'].transform(lambda x: np.mean(x) ==1)
#Set a measure all phonemes missing
df.loc[:,('AllPhonsMiss')] = df.groupby('WordCount')['PhonemeHitBool'].transform(lambda x: np.mean(x) ==0)
# Make a column for the number of words in the sentence
df['NumWordsInSentence'] = df.groupby(['SentenceCount'])['WordIdx'].transform(max)+1

#Remove practice speaker (and last speaker)
df = df[df.Speaker != 's59F'] 
df.keys()
# Out:
# Index([u'index', u'Unnamed: 0.1', u'VideoFile', u'TargetSentence', u'Babble',
#        u'TrialNum', u'SpellCorrSource', u'SourceSentence', u'Speaker',
#        u'SentenceWordScore', u'dBSNR', u'Subject', u'SentenceType',
#        u'VideoCond', u'BabbleCond', u'FileName', u'VerbalResponse',
#        u'1LogGram', u'2LogGram', u'3LogGram', u'Indx', u'Word', u'UnTrn',
#        u'StTrn', u'NSyll', u'NPhon', u'unsDENS', u'unsFDEN', u'unsLDEN',
#        u'unsCDEN', u'strDENS', u'strFDEN', u'strLDEN', u'strCDEN', u'unsBPAV',
#        u'unsFBPAV', u'unsLBPAV', u'unsCBPAV', u'strBPAV', u'strFBPAV',
#        u'strLBPAV', u'strCBPAV', u'unsTPAV', u'unsFTPAV', u'unsLTPAV',
#        u'unsCTPAV', u'strTPAV', u'strFTPAV', u'strLTPAV', u'strCTPAV',
#        u'unsPOSPAV', u'unsFPOSPAV', u'unsLPOSPAV', u'unsCPOSPAV', u'strPOSPAV',
#        u'strFPOSPAV', u'strLPOSPAV', u'strCPOSPAV', u'unsLCPOSPAV',
#        u'unsFLCPOSPAV', u'unsLLCPOSPAV', u'unsCLCPOSPAV', u'strLCPOSPAV',
#        u'strFLCPOSPAV', u'strLLCPOSPAV', u'strCLCPOSPAV', u'SFreq', u'SCDcnt',
#        u'PhonemeCount', u'PhonemeIndex', u'TargetPhoneme', u'SourcePhoneme',
#        u'PhonemeHitBool', u'WordCount', u'WordIdx', u'TargetWord',
#        u'SourceWord', u'WordACC', u'SentenceCount', u'AllPhonsMatch',
#        u'AllPhonsMiss', u'NumWordsInSentence'],
#       dtype='object')

# %%
#Make plots prettier
#Edited from Randel Olson and many at StackOverflow
# These are the "Tableau 20" colors as RGB.    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.) 


plt.rc('text', color = 'black') 
plt.rc('font', family='sans-serif') 
plt.rc('font', serif='Helvetica Neue') 
plt.rc('axes', titlesize = 18, labelsize = 14,labelcolor ='black')  
plt.rc('lines', linewidth=2,markersize = 10)
plt.rc('xtick',labelsize = 10,color ='black')
plt.rc('ytick',labelsize = 10,color ='black')
def hide_spines():
    """Hides the top and rightmost axis spines from view for all active
    figures and their respective axes."""

    # Retrieve a list of all current figures.
    figures = [x for x in plt._pylab_helpers.Gcf.get_all_fig_managers()]
    for figure in figures:
        # Get all Axis instances related to the figure.
        for ax in figure.canvas.figure.get_axes():
            # Disable spines.
            ax.spines['right'].set_color('none')
            ax.spines['top'].set_color('none')
            # Disable ticks.
            ax.xaxis.set_ticks_position('bottom')
            ax.yaxis.set_ticks_position('left')
# %matplotlib inline

# %%
df
# Out:
#        index  Unnamed: 0.1                                          VideoFile  \
# 362        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 363        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 364        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 365        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 366        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 367        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 368        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 369        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 370        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 371        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 372        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 373        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 374        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 375        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 376        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 377        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 378        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 379        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 380        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 381        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 382        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 383        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 384        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 385        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 386        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 387        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 388        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 389        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 390        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# 391        0             0  C:/TCDTIMIT/volunteersSmall/s01M/straightcam/s...
# ...      ...           ...                                                ...
# 64363     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64364     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64365     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64366     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64367     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64368     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64369     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64370     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64371     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64372     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64373     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64374     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64375     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64376     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64377     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64378     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64379     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64380     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64381     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64382     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64383     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64384     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64385     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64386     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64387     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64388     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64389     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64390     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64391     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
# 64392     31            31  C:/TCDTIMIT/volunteersSmall/s58F/straightcam/s...
#
#                                           TargetSentence    Babble  TrialNum  \
# 362    urethane foam as an insulator is also coming i...  babble21         0
# 363    urethane foam as an insulator is also coming i...  babble21         0
# 364    urethane foam as an insulator is also coming i...  babble21         0
# 365    urethane foam as an insulator is also coming i...  babble21         0
# 366    urethane foam as an insulator is also coming i...  babble21         0
# 367    urethane foam as an insulator is also coming i...  babble21         0
# 368    urethane foam as an insulator is also coming i...  babble21         0
# 369    urethane foam as an insulator is also coming i...  babble21         0
# 370    urethane foam as an insulator is also coming i...  babble21         0
# 371    urethane foam as an insulator is also coming i...  babble21         0
# 372    urethane foam as an insulator is also coming i...  babble21         0
# 373    urethane foam as an insulator is also coming i...  babble21         0
# 374    urethane foam as an insulator is also coming i...  babble21         0
# 375    urethane foam as an insulator is also coming i...  babble21         0
# 376    urethane foam as an insulator is also coming i...  babble21         0
# 377    urethane foam as an insulator is also coming i...  babble21         0
# 378    urethane foam as an insulator is also coming i...  babble21         0
# 379    urethane foam as an insulator is also coming i...  babble21         0
# 380    urethane foam as an insulator is also coming i...  babble21         0
# 381    urethane foam as an insulator is also coming i...  babble21         0
# 382    urethane foam as an insulator is also coming i...  babble21         0
# 383    urethane foam as an insulator is also coming i...  babble21         0
# 384    urethane foam as an insulator is also coming i...  babble21         0
# 385    urethane foam as an insulator is also coming i...  babble21         0
# 386    urethane foam as an insulator is also coming i...  babble21         0
# 387    urethane foam as an insulator is also coming i...  babble21         0
# 388    urethane foam as an insulator is also coming i...  babble21         0
# 389    urethane foam as an insulator is also coming i...  babble21         0
# 390    urethane foam as an insulator is also coming i...  babble21         0
# 391    urethane foam as an insulator is also coming i...  babble21         0
# ...                                                  ...       ...       ...
# 64363  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64364  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64365  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64366  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64367  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64368  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64369  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64370  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64371  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64372  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64373  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64374  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64375  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64376  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64377  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64378  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64379  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64380  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64381  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64382  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64383  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64384  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64385  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64386  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64387  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64388  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64389  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64390  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64391  herb's birthday occurs frequently on thanksgiving  babble16        31
# 64392  herb's birthday occurs frequently on thanksgiving  babble16        31
#
#                                          SpellCorrSource  \
# 362    youre a thin foam as an insulator is also a go...
# 363    youre a thin foam as an insulator is also a go...
# 364    youre a thin foam as an insulator is also a go...
# 365    youre a thin foam as an insulator is also a go...
# 366    youre a thin foam as an insulator is also a go...
# 367    youre a thin foam as an insulator is also a go...
# 368    youre a thin foam as an insulator is also a go...
# 369    youre a thin foam as an insulator is also a go...
# 370    youre a thin foam as an insulator is also a go...
# 371    youre a thin foam as an insulator is also a go...
# 372    youre a thin foam as an insulator is also a go...
# 373    youre a thin foam as an insulator is also a go...
# 374    youre a thin foam as an insulator is also a go...
# 375    youre a thin foam as an insulator is also a go...
# 376    youre a thin foam as an insulator is also a go...
# 377    youre a thin foam as an insulator is also a go...
# 378    youre a thin foam as an insulator is also a go...
# 379    youre a thin foam as an insulator is also a go...
# 380    youre a thin foam as an insulator is also a go...
# 381    youre a thin foam as an insulator is also a go...
# 382    youre a thin foam as an insulator is also a go...
# 383    youre a thin foam as an insulator is also a go...
# 384    youre a thin foam as an insulator is also a go...
# 385    youre a thin foam as an insulator is also a go...
# 386    youre a thin foam as an insulator is also a go...
# 387    youre a thin foam as an insulator is also a go...
# 388    youre a thin foam as an insulator is also a go...
# 389    youre a thin foam as an insulator is also a go...
# 390    youre a thin foam as an insulator is also a go...
# 391    youre a thin foam as an insulator is also a go...
# ...                                                  ...
# 64363                     her birthday occurs frequently
# 64364                     her birthday occurs frequently
# 64365                     her birthday occurs frequently
# 64366                     her birthday occurs frequently
# 64367                     her birthday occurs frequently
# 64368                     her birthday occurs frequently
# 64369                     her birthday occurs frequently
# 64370                     her birthday occurs frequently
# 64371                     her birthday occurs frequently
# 64372                     her birthday occurs frequently
# 64373                     her birthday occurs frequently
# 64374                     her birthday occurs frequently
# 64375                     her birthday occurs frequently
# 64376                     her birthday occurs frequently
# 64377                     her birthday occurs frequently
# 64378                     her birthday occurs frequently
# 64379                     her birthday occurs frequently
# 64380                     her birthday occurs frequently
# 64381                     her birthday occurs frequently
# 64382                     her birthday occurs frequently
# 64383                     her birthday occurs frequently
# 64384                     her birthday occurs frequently
# 64385                     her birthday occurs frequently
# 64386                     her birthday occurs frequently
# 64387                     her birthday occurs frequently
# 64388                     her birthday occurs frequently
# 64389                     her birthday occurs frequently
# 64390                     her birthday occurs frequently
# 64391                     her birthday occurs frequently
# 64392                     her birthday occurs frequently
#
#                                           SourceSentence Speaker  \
# 362    You're a thin foam as an insulator is also a g...    s01M
# 363    You're a thin foam as an insulator is also a g...    s01M
# 364    You're a thin foam as an insulator is also a g...    s01M
# 365    You're a thin foam as an insulator is also a g...    s01M
# 366    You're a thin foam as an insulator is also a g...    s01M
# 367    You're a thin foam as an insulator is also a g...    s01M
# 368    You're a thin foam as an insulator is also a g...    s01M
# 369    You're a thin foam as an insulator is also a g...    s01M
# 370    You're a thin foam as an insulator is also a g...    s01M
# 371    You're a thin foam as an insulator is also a g...    s01M
# 372    You're a thin foam as an insulator is also a g...    s01M
# 373    You're a thin foam as an insulator is also a g...    s01M
# 374    You're a thin foam as an insulator is also a g...    s01M
# 375    You're a thin foam as an insulator is also a g...    s01M
# 376    You're a thin foam as an insulator is also a g...    s01M
# 377    You're a thin foam as an insulator is also a g...    s01M
# 378    You're a thin foam as an insulator is also a g...    s01M
# 379    You're a thin foam as an insulator is also a g...    s01M
# 380    You're a thin foam as an insulator is also a g...    s01M
# 381    You're a thin foam as an insulator is also a g...    s01M
# 382    You're a thin foam as an insulator is also a g...    s01M
# 383    You're a thin foam as an insulator is also a g...    s01M
# 384    You're a thin foam as an insulator is also a g...    s01M
# 385    You're a thin foam as an insulator is also a g...    s01M
# 386    You're a thin foam as an insulator is also a g...    s01M
# 387    You're a thin foam as an insulator is also a g...    s01M
# 388    You're a thin foam as an insulator is also a g...    s01M
# 389    You're a thin foam as an insulator is also a g...    s01M
# 390    You're a thin foam as an insulator is also a g...    s01M
# 391    You're a thin foam as an insulator is also a g...    s01M
# ...                                                  ...     ...
# 64363                     Her birthday occurs frequently    s58F
# 64364                     Her birthday occurs frequently    s58F
# 64365                     Her birthday occurs frequently    s58F
# 64366                     Her birthday occurs frequently    s58F
# 64367                     Her birthday occurs frequently    s58F
# 64368                     Her birthday occurs frequently    s58F
# 64369                     Her birthday occurs frequently    s58F
# 64370                     Her birthday occurs frequently    s58F
# 64371                     Her birthday occurs frequently    s58F
# 64372                     Her birthday occurs frequently    s58F
# 64373                     Her birthday occurs frequently    s58F
# 64374                     Her birthday occurs frequently    s58F
# 64375                     Her birthday occurs frequently    s58F
# 64376                     Her birthday occurs frequently    s58F
# 64377                     Her birthday occurs frequently    s58F
# 64378                     Her birthday occurs frequently    s58F
# 64379                     Her birthday occurs frequently    s58F
# 64380                     Her birthday occurs frequently    s58F
# 64381                     Her birthday occurs frequently    s58F
# 64382                     Her birthday occurs frequently    s58F
# 64383                     Her birthday occurs frequently    s58F
# 64384                     Her birthday occurs frequently    s58F
# 64385                     Her birthday occurs frequently    s58F
# 64386                     Her birthday occurs frequently    s58F
# 64387                     Her birthday occurs frequently    s58F
# 64388                     Her birthday occurs frequently    s58F
# 64389                     Her birthday occurs frequently    s58F
# 64390                     Her birthday occurs frequently    s58F
# 64391                     Her birthday occurs frequently    s58F
# 64392                     Her birthday occurs frequently    s58F
#
#        SentenceWordScore         ...          PhonemeHitBool WordCount  \
# 362                   60         ...                   False        87
# 363                   60         ...                   False        87
# 364                   60         ...                    True        87
# 365                   60         ...                    True        87
# 366                   60         ...                   False        87
# 367                   60         ...                    True        87
# 368                   60         ...                    True        88
# 369                   60         ...                    True        88
# 370                   60         ...                    True        88
# 371                   60         ...                    True        89
# 372                   60         ...                    True        89
# 373                   60         ...                    True        90
# 374                   60         ...                    True        90
# 375                   60         ...                    True        91
# 376                   60         ...                    True        91
# 377                   60         ...                    True        91
# 378                   60         ...                    True        91
# 379                   60         ...                    True        91
# 380                   60         ...                    True        91
# 381                   60         ...                    True        91
# 382                   60         ...                    True        91
# 383                   60         ...                    True        92
# 384                   60         ...                    True        92
# 385                   60         ...                    True        93
# 386                   60         ...                    True        93
# 387                   60         ...                    True        93
# 388                   60         ...                    True        93
# 389                   60         ...                   False        94
# 390                   60         ...                   False        94
# 391                   60         ...                   False        94
# ...                  ...         ...                     ...       ...
# 64363                 50         ...                    True     15249
# 64364                 50         ...                    True     15249
# 64365                 50         ...                    True     15249
# 64366                 50         ...                    True     15249
# 64367                 50         ...                    True     15250
# 64368                 50         ...                    True     15250
# 64369                 50         ...                    True     15250
# 64370                 50         ...                    True     15250
# 64371                 50         ...                    True     15251
# 64372                 50         ...                    True     15251
# 64373                 50         ...                    True     15251
# 64374                 50         ...                    True     15251
# 64375                 50         ...                    True     15251
# 64376                 50         ...                    True     15251
# 64377                 50         ...                    True     15251
# 64378                 50         ...                    True     15251
# 64379                 50         ...                    True     15251
# 64380                 50         ...                    True     15251
# 64381                 50         ...                   False     15252
# 64382                 50         ...                   False     15252
# 64383                 50         ...                   False     15253
# 64384                 50         ...                   False     15253
# 64385                 50         ...                   False     15253
# 64386                 50         ...                   False     15253
# 64387                 50         ...                   False     15253
# 64388                 50         ...                   False     15253
# 64389                 50         ...                   False     15253
# 64390                 50         ...                   False     15253
# 64391                 50         ...                   False     15253
# 64392                 50         ...                   False     15253
#
#       WordIdx    TargetWord  SourceWord WordACC SentenceCount  AllPhonsMatch  \
# 362         1      urethane        thin       0            10          False
# 363         1      urethane        thin       0            10          False
# 364         1      urethane        thin       0            10          False
# 365         1      urethane        thin       0            10          False
# 366         1      urethane        thin       0            10          False
# 367         1      urethane        thin       0            10          False
# 368         2          foam        foam       1            10           True
# 369         2          foam        foam       1            10           True
# 370         2          foam        foam       1            10           True
# 371         3            as          as       1            10           True
# 372         3            as          as       1            10           True
# 373         4            an          an       1            10           True
# 374         4            an          an       1            10           True
# 375         5     insulator   insulator       1            10           True
# 376         5     insulator   insulator       1            10           True
# 377         5     insulator   insulator       1            10           True
# 378         5     insulator   insulator       1            10           True
# 379         5     insulator   insulator       1            10           True
# 380         5     insulator   insulator       1            10           True
# 381         5     insulator   insulator       1            10           True
# 382         5     insulator   insulator       1            10           True
# 383         6            is          is       1            10           True
# 384         6            is          is       1            10           True
# 385         7          also        also       1            10           True
# 386         7          also        also       1            10           True
# 387         7          also        also       1            10           True
# 388         7          also        also       1            10           True
# 389         8        coming           -       0            10          False
# 390         8        coming           -       0            10          False
# 391         8        coming           -       0            10          False
# ...       ...           ...         ...     ...           ...            ...
# 64363       2      birthday    birthday       1          1945           True
# 64364       2      birthday    birthday       1          1945           True
# 64365       2      birthday    birthday       1          1945           True
# 64366       2      birthday    birthday       1          1945           True
# 64367       3        occurs      occurs       1          1945           True
# 64368       3        occurs      occurs       1          1945           True
# 64369       3        occurs      occurs       1          1945           True
# 64370       3        occurs      occurs       1          1945           True
# 64371       4    frequently  frequently       1          1945           True
# 64372       4    frequently  frequently       1          1945           True
# 64373       4    frequently  frequently       1          1945           True
# 64374       4    frequently  frequently       1          1945           True
# 64375       4    frequently  frequently       1          1945           True
# 64376       4    frequently  frequently       1          1945           True
# 64377       4    frequently  frequently       1          1945           True
# 64378       4    frequently  frequently       1          1945           True
# 64379       4    frequently  frequently       1          1945           True
# 64380       4    frequently  frequently       1          1945           True
# 64381       5            on           -       0          1945          False
# 64382       5            on           -       0          1945          False
# 64383       6  thanksgiving           -       0          1945          False
# 64384       6  thanksgiving           -       0          1945          False
# 64385       6  thanksgiving           -       0          1945          False
# 64386       6  thanksgiving           -       0          1945          False
# 64387       6  thanksgiving           -       0          1945          False
# 64388       6  thanksgiving           -       0          1945          False
# 64389       6  thanksgiving           -       0          1945          False
# 64390       6  thanksgiving           -       0          1945          False
# 64391       6  thanksgiving           -       0          1945          False
# 64392       6  thanksgiving           -       0          1945          False
#
#        AllPhonsMiss  NumWordsInSentence
# 362           False                  16
# 363           False                  16
# 364           False                  16
# 365           False                  16
# 366           False                  16
# 367           False                  16
# 368           False                  16
# 369           False                  16
# 370           False                  16
# 371           False                  16
# 372           False                  16
# 373           False                  16
# 374           False                  16
# 375           False                  16
# 376           False                  16
# 377           False                  16
# 378           False                  16
# 379           False                  16
# 380           False                  16
# 381           False                  16
# 382           False                  16
# 383           False                  16
# 384           False                  16
# 385           False                  16
# 386           False                  16
# 387           False                  16
# 388           False                  16
# 389            True                  16
# 390            True                  16
# 391            True                  16
# ...             ...                 ...
# 64363         False                   7
# 64364         False                   7
# 64365         False                   7
# 64366         False                   7
# 64367         False                   7
# 64368         False                   7
# 64369         False                   7
# 64370         False                   7
# 64371         False                   7
# 64372         False                   7
# 64373         False                   7
# 64374         False                   7
# 64375         False                   7
# 64376         False                   7
# 64377         False                   7
# 64378         False                   7
# 64379         False                   7
# 64380         False                   7
# 64381          True                   7
# 64382          True                   7
# 64383          True                   7
# 64384          True                   7
# 64385          True                   7
# 64386          True                   7
# 64387          True                   7
# 64388          True                   7
# 64389          True                   7
# 64390          True                   7
# 64391          True                   7
# 64392          True                   7
#
# [61135 rows x 82 columns]

# %% [markdown]
# ### How much does lip reading improve phonemic perception of clear vs noisy speech?

# %%
videoByBabble = df[['VideoCond','BabbleCond','PhonemeHitBool']].groupby(['BabbleCond','VideoCond']).mean().unstack()
videoByBabble
#ax = videoByBabble.plot(kind = 'bar',color = tableau20[0:1])
ax = videoByBabble.plot(kind ='bar',figsize = (6,4), color = [tableau20[x] for x in [0,5]])
ax.set_ylabel('Phoneme Accuracy')
ax.set_xlabel('Noise Level')
ax.legend(loc='best',labels = ['Audiovisual','Auditory Only'])

# %% [markdown]
# Do we replicate Sumby and Pollack (1954)?  That is to say, do we find that the ratio of AV improvement over AO is roughly constant?  Calculated as (AOerrors-AVerrors)/AOerrors

# %%
videoByBabbleInvert = 1-videoByBabble.loc[:,:]
av = videoByBabbleInvert.xs('Audiovisual',level = 1,axis=1)
ao = videoByBabbleInvert.xs('Auditory Only',level = 1,axis=1)
sumbyRatio = ((ao-av)/ao)
videoByBabbleInvert['PhonemeHitBool','SumbyRatio'] = sumbyRatio
videoByBabbleInvert
# Out:
#            PhonemeHitBool
# VideoCond     Audiovisual Auditory Only SumbyRatio
# BabbleCond
# Clear            0.114954      0.151261   0.240027
# Noisy            0.378827      0.541863   0.300881

# %% [markdown]
# Looks like in our case the amount phonemic improvement under noisy conditions is not only numerically higher, it's a somewhat higher ratio of improvement. However, it could be that our listening "ceiling" is less than 100% in practice, due to loss in working memory, spelling errors or accent confusion. We can examine the working memory issue by selecting only short sentences

# %%
#Short Sentence Analysis
videoByBabble = df[['VideoCond','BabbleCond','PhonemeHitBool']].loc[df['NumWordsInSentence'] < 10,:].groupby(['BabbleCond','VideoCond']).mean().unstack()
videoByBabble
#ax = videoByBabble.plot(kind = 'bar',color = tableau20[0:1])
ax = videoByBabble.plot(kind ='bar',figsize = (6,4), color = [tableau20[x] for x in [0,5]])
ax.set_ylabel('Phoneme Accuracy')
ax.set_xlabel('Noise Level')
ax.legend(loc='best',labels = ['Audiovisual','Auditory Only'])
plt.figure()
videoByBabbleInvert = 1-videoByBabble.loc[:,:]
av = videoByBabbleInvert.xs('Audiovisual',level = 1,axis=1)
ao = videoByBabbleInvert.xs('Auditory Only',level = 1,axis=1)
sumbyRatio = ((ao-av)/ao)
videoByBabbleInvert['PhonemeHitBool','SumbyRatio'] = sumbyRatio
videoByBabbleInvert
# Out:
#            PhonemeHitBool
# VideoCond     Audiovisual Auditory Only SumbyRatio
# BabbleCond
# Clear            0.069794      0.073282   0.047601
# Noisy            0.322838      0.487122   0.337255

# %% [markdown]
# Huh, that's weird. For short sentences the difference in AV improvement between clear and noisy is even greater? How about if we pick only long sentences?

# %%
data = df[['NumWordsInSentence','SentenceCount']].groupby('NumWordsInSentence').count()
ax = data.plot(kind = 'line',figsize= (8,4),legend = None)
ax.set_ylabel('Count')

data = df[['NumWordsInSentence','SentenceCount']].groupby('NumWordsInSentence').count().cumsum()
ax = data.plot(kind = 'line',figsize= (8,4),legend = None)
ax.set_ylabel('Cumulative Count')

# %%
#Long sentence analysis
videoByBabble = df[['VideoCond','BabbleCond','PhonemeHitBool']].loc[df['NumWordsInSentence'] >= 10,:].groupby(['BabbleCond','VideoCond']).mean().unstack()
videoByBabble
#ax = videoByBabble.plot(kind = 'bar',color = tableau20[0:1])
ax = videoByBabble.plot(kind ='bar',figsize = (6,4), color = [tableau20[x] for x in [0,5]])
ax.set_ylabel('Phoneme Accuracy')
ax.set_xlabel('Noise Level')
ax.legend(loc='best',labels = ['Audiovisual','Auditory Only'])
plt.figure()
videoByBabbleInvert = 1-videoByBabble.loc[:,:]
av = videoByBabbleInvert.xs('Audiovisual',level = 1,axis=1)
ao = videoByBabbleInvert.xs('Auditory Only',level = 1,axis=1)
sumbyRatio = ((ao-av)/ao)
videoByBabbleInvert['PhonemeHitBool','SumbyRatio'] = sumbyRatio
videoByBabbleInvert
# Out:
#            PhonemeHitBool
# VideoCond     Audiovisual Auditory Only SumbyRatio
# BabbleCond
# Clear            0.213322      0.250708   0.149120
# Noisy            0.490573      0.645701   0.240247

# %% [markdown]
# Weird, the visual info is more helpful for longer sentences under clear conditions, but less so under noisy conditions.

# %% [markdown]
# ### Does the contribution of visual information to phonemic perception change over the course of a sentence?

# %%
#Instances by word position in sentence
data = df[['PhonemeHitBool','WordIdx','WordCount']].groupby('WordCount').mean().groupby('WordIdx').count()
ax = data.plot(kind='line',figsize=(8,4),color = tableau20[0],legend = None )
ax.set_title('Words per Word Position')
ax.set_xlabel('Nth Word')
ax.set_ylabel('Count')
hide_spines()

# %% [markdown]
# At higher word positions, we have fewer instances to draw from. We'll limit or view to word positions 12 or fewer to have enough instances per condition to draw conclusions.

# %%
#Instances by word position in sentence
data = df[['WordACC','WordIdx','WordCount']].groupby('WordCount').mean().groupby('WordIdx').mean()[0:12]
ax = data.plot(kind='line',figsize=(8,4),color = tableau20[0],legend = None )
ax.set_title('Word Accuracy by Word Position')
ax.set_xlabel('Nth Word')
ax.set_ylabel('Word Accuracy')
hide_spines()

# %% [markdown]
# We have a lovely linearish negative relationship between phoneme accuracy and word position. Wow! >30% drop between the first and 12th word. Same result for phoneme accuracy?

# %%
#Instances by word position in sentence
data = df[['PhonemeHitBool','WordIdx','WordCount']].groupby('WordCount').mean().groupby('WordIdx').mean()[0:12]
ax = data.plot(kind='line',figsize=(8,4),color = tableau20[0],legend = None )
ax.set_title('Phoneme Accuracy by Word Position')
ax.set_xlabel('Nth Word')
ax.set_ylabel('Phoneme Accuracy')
hide_spines()

# %% [markdown]
# Yup! Phoneme accuracy will be a bit higher overall to account for partially correct responses. Trend is the same though. Lets make this more interesting by splitting it up by condition.

# %%
data = df[['PhonemeHitBool','WordIdx','WordCount','VideoCond','BabbleCond']].groupby(['VideoCond','BabbleCond','WordCount']).mean()
data = data.reset_index().groupby(['WordIdx','VideoCond','BabbleCond']).mean().unstack().unstack()['PhonemeHitBool'][0:12]
ax = data.plot(kind ='line',figsize=(7,7),color = [tableau20[x] for x in [0,1,2,3]])
ax.legend(loc='best')
ax.set_ylabel('Phoneme Accuracy')
ax.set_xlabel('Word Position in Sentence')
hide_spines()

# %% [markdown]
# There are some bumps on the curve, but it looks like the AV advantage is realatively constant throughout the sentence. The slope of phonemic loss over the sentence is a bit steeper for the Noisy Condition.

# %%
av = 1-data.xs('Audiovisual',level = 1,axis=1)
ao = 1-data.xs('Auditory Only',level = 1,axis=1)
sumbyRatio = (ao-av)/ao
ax = sumbyRatio.plot(kind ='line',figsize=(7,7),color = [tableau20[x] for x in [0,1]])
ax.legend(loc='best')
ax.set_ylabel('SumbyRatio')
ax.set_xlabel('Word Position in Sentence')
hide_spines()

# %% [markdown]
# It's a bit noisy, but you can generally see a higher Sumby Ratio for Noisy sentences, as well as a decline in the Sumby ratio with increasing sentence length.

# %% [markdown]
# ### Do some phonemes benefit from speechreading more than others?

# %%
data = df.loc[df['BabbleCond'] =='Noisy',:]
#a= data['AllPhonsMatch'] == False 
#b = data['AllPhonsMiss'] == False
#boolIdx =a&b 
#data = data.loc[boolIdx,:]
data = data[['TargetPhoneme','PhonemeHitBool','VideoCond']].groupby(['TargetPhoneme']).sum()
instances = data
data = data.sort_values('PhonemeHitBool')
ax = data.plot(kind = 'bar',figsize=(12,4))
ax.legend(loc='best')
ax.set_ylabel('Noisy Instances')

# %%
data = df.loc[df['BabbleCond'] =='Noisy',:]

#Only look at partially correct words
#a= data['AllPhonsMatch'] == False 
#b = data['AllPhonsMiss'] == False
#boolIdx =a&b 
#data = data.loc[boolIdx,:]

data = data[['TargetPhoneme','PhonemeHitBool','VideoCond']].groupby(['TargetPhoneme','VideoCond']).mean()
data = data.unstack()
ax = data.plot(kind = 'bar',figsize=(12,4))
ax.legend(loc='lower right')
ax.set_ylabel('Noisy Percent Correct')
avNoisyPHit = data['PhonemeHitBool','Audiovisual']
aoNoisyPHit = data['PhonemeHitBool','Auditory Only']

# %%
data = df.loc[df['BabbleCond'] =='Noisy',:]

#Only look at partially correct words
#a= data['AllPhonsMatch'] == False 
#b = data['AllPhonsMiss'] == False
#boolIdx =a&b 
#data = data.loc[boolIdx,:]

data = data[['TargetPhoneme','PhonemeHitBool','VideoCond']].groupby(['TargetPhoneme','VideoCond']).sum()
data = data.unstack()
ax = data.plot(kind = 'bar',figsize=(12,4))
ax.legend(loc='best')
ax.set_ylabel('Noisy Percent Correct')
avNoisyPHitSum = data['PhonemeHitBool','Audiovisual']
aoNoisyPHitSum = data['PhonemeHitBool','Auditory Only']

# %%
avGain = avNoisyPHitSum-aoNoisyPHitSum
avGainRank = avGain.rank(ascending = False)
avGain.name = 'Count'
data = avGain.sort_values()
ax = data.plot(kind = 'bar',figsize=(12,4))
ax.legend(loc='lower right')
ax.set_ylabel('AV Correct-AO Correct Sums')

# %%
# Out:
#                PhonemeHitBool
# TargetPhoneme
#                            42
# A                          42
# AA                         16
# AE                         24
# AH                         29
# AO                          5
# AW                         27
# AY                         10
# B                          13
# CH                         35
# D                          36
# DH                         15
# E                          42
# EH                         22
# ER                         19
# EY                          3
# F                          17
# G                          28
# H                          42
# HH                         23
# I                          42
# IH                         30
# IY                         33
# JH                          1
# K                          25
# L                          14
# M                          34
# N                          32
# NG                          6
# OW                         18
# OY                          2
# P                           7
# R                          12
# S                          26
# SH                         31
# T                          21
# TH                         38
# UH                         11
# UW                          8
# V                          20
# W                           9
# Y                           4
# Z                          37
# ZH                         39

# %%
data = df.loc[df['BabbleCond'] =='Noisy',:]

#Only look at partially correct words
#a= data['AllPhonsMatch'] == False 
#b = data['AllPhonsMiss'] == False
#boolIdx =a&b 
#data = data.loc[boolIdx,:]

data = data[['TargetPhoneme','PhonemeHitBool','VideoCond']].groupby(['TargetPhoneme','VideoCond']).mean()
data = data.unstack()
av = 1-data.xs('Audiovisual',level = 1,axis=1)
ao = 1-data.xs('Auditory Only',level = 1,axis=1)
sumbyRatio = (ao-av)/ao
data = data.join(sumbyRatio)
#instances.name = 'Count'
#data = data.join(instances)
data.columns = ['AV','AO','SumbyRatio']
data = data.sort_values('SumbyRatio')
ax =data['SumbyRatio'].plot(kind ='bar',figsize=(12,4),legend = None)
ax.set_ylabel('Sumby Ratio')

# %% [markdown]
# Yay! AV weights for all noisy phonemes!

# %%
import os
dfPT = pd.read_excel(os.path.normpath('C:\TCDTIMIT\Tables\Custom\TablesPhoneme.xlsx'),encoding='latin-1')
sumbyRank = sumbyRatio.rank()
aoNoisyRank = aoNoisyPHit.rank()
avNoisyRank = avNoisyPHit.rank()
rankDif = avNoisyRank-aoNoisyRank
rankDifNorm = (rankDif-min(rankDif))/max(rankDif-min(rankDif))
rankDifNorm
# Out:
# TargetPhoneme
#       0.473684
# A     0.508772
# AA    0.508772
# AE    0.543860
# AH    0.228070
# AO    0.614035
# AW    0.526316
# AY    0.631579
# B     0.666667
# CH    0.333333
# D     0.385965
# DH    0.298246
# E     0.543860
# EH    0.333333
# ER    0.350877
# EY    0.701754
# F     0.842105
# G     0.543860
# H     0.491228
# HH    0.666667
# I     0.526316
# IH    0.561404
# IY    0.087719
# JH    0.526316
# K     0.491228
# L     0.614035
# M     0.000000
# N     0.315789
# NG    1.000000
# OW    0.315789
# OY    0.491228
# P     0.859649
# R     0.561404
# S     0.596491
# SH    0.631579
# T     0.456140
# TH    0.245614
# UH    0.421053
# UW    0.508772
# V     0.771930
# W     0.684211
# Y     0.508772
# Z     0.508772
# ZH    0.508772
# dtype: float64

# %% [markdown]
# Let's visualize the advantage of having visual information at the phonetic level a better way, with the help of an interactive phonetic chart! Lots of code below so be patient!

# %%
global cmaps
def BokehTable(cmaps):
    from bokeh.models import HoverTool, ColumnDataSource,CustomJS
    from bokeh.plotting import figure, show, output_file
    import pandas as pd
    import os
    from bokeh.io import output_notebook,vform,push_notebook
    global source
    

    cmap = cmaps[0]
    output_notebook()
    #dfPT = pd.DataFrame.from_csv(os.path.normpath('C:\TCDTIMIT\Tables\Custom\TablesPhoneme.csv'))
    dfPT = pd.read_excel(os.path.normpath('C:\TCDTIMIT\Tables\Custom\TablesPhoneme.xlsx'),encoding='latin-1')
    #cmap = [aoNoisyRank.loc[aoNoisyRank.index == cmu].values[0] for cmu in dfPT['CMU Phonemes'][0:39]]/max(aoNoisyRank.values)
    #cmap = [rankDifNorm.loc[rankDifNorm.index == cmu].values[0] for cmu in dfPT['CMU Phonemes'][0:39]]/max(rankDifNorm.values)
        
    source = ColumnDataSource(
        data=dict(
            xaxis=[str(x) for x in dfPT['AdrianXCoord']],
            yaxis=[str(y) for y in dfPT['AdrianYCoord']],
            cmu=[str(s) for s in dfPT['CMU Phonemes']],
            type=[str(x) for x in cmap],
            sym=[x for x in dfPT['IPA symbol']],
            jrank=[x for x in dfPT['Jeffers Visibility Rank']],
            mpcrank=[x for x in dfPT['MPC Rank']], 
            gvrank=[x for x in dfPT['Gillen Based Visual Weight'].rank(ascending=False)],
            gaorank=[x for x in dfPT['Gillen Audio Only Clear Hit Rate'].rank(ascending=False)],
            example=[x for x in dfPT['CMU Examples']],   
            type_color = ['#%02x%02x%02x' % (x*255,255-(x*255),0) for x in cmap] #Must be hexadecima
        )
    )

    p = figure(tools="resize,hover,save")
    p.plot_width = 1200
    p.toolbar_location = None
    p.outline_line_color = None

    p.rect("xaxis", "yaxis", 0.9, 0.9, source=source,
           fill_alpha=0.6, color="type_color")

    #p.rect("xaxis", "yaxis", 0.9, 0.9, source=source,
    #       fill_alpha=0.6)

    text_props = {
        "source": source,
        "angle": 0,
        "color": "black",
        "text_align": "left",
        "text_baseline": "middle"
    }

    p.text(x="xaxis", y="yaxis", text="sym",
           text_font_style="bold", text_font_size="15pt", **text_props)



    p.grid.grid_line_color = None

    p.select_one(HoverTool).tooltips = [
        ("cmu", "@cmu"),
        ("example", "@example"),
        ("jrank","@jrank"),
        ("mpcrank","@mpcrank"),
        ("gaorank","@gaorank"),
        ("gvrank","@gvrank"),

    ]
    show(p) 
    
def update(f):
    from bokeh.io import push_notebook
    cmap = cmaps[titles.index(f)] 
    type_color = ['#%02x%02x%02x' % (x*255,255-(x*255),0) for x in cmap]
    source.data['type_color'] = type_color
    push_notebook()

# %%
data = df.loc[df['BabbleCond'] =='Noisy',:]

#Only look at partially correct words
a= data['AllPhonsMatch'] == False 
b = data['AllPhonsMiss'] == False
boolIdx =a&b 
data = data.loc[boolIdx,:]

data = data[['TargetPhoneme','PhonemeHitBool','VideoCond']].groupby(['TargetPhoneme','VideoCond']).mean()
data = data.unstack()
ao = data.xs('Auditory Only',level = 1,axis=1)
av = data.xs('Audiovisual',level = 1,axis=1)
aoRank = ao.rank(ascending = False)
avRank = av.rank(ascending = False)
sumbyRatio = ((1-ao)-(1-av))/(1-ao)
sumbyRank = sumbyRatio.rank(ascending = False)
dfPT = pd.read_excel(os.path.normpath('C:\TCDTIMIT\Tables\Custom\TablesPhoneme.xlsx'),encoding='latin-1')

cmaps =[]
titles =[]

Jeffers = dfPT['Jeffers Visibility Rank']
titles.append('Jeffers Visibility Map')
cmaps.append(Jeffers/max(Jeffers))

MPC = dfPT['MPC Rank']
titles.append('Movement-to-Phonetic Correspondance Map')
cmaps.append(MPC/max(MPC))

titles.append('Sumby Noisy Visibility Map')
cmaps.append([sumbyRank.loc[sumbyRank.index == cmu].values[0][0] for cmu in dfPT['CMU Phonemes'][0:39]]/max(sumbyRank.values))

titles.append('Auditory Only Noisy Rank Map')
cmaps.append([aoRank.loc[aoRank.index == cmu].values[0][0] for cmu in dfPT['CMU Phonemes'][0:39]]/max(aoRank.values)) 

titles.append('Audiovisual Noisy Rank Map')
cmaps.append([avRank.loc[avRank.index == cmu].values[0][0] for cmu in dfPT['CMU Phonemes'][0:39]]/max(avRank.values)) 

titles.append('AV Gain Raw Rank')
cmaps.append([avGainRank[avGainRank.index == cmu].values for cmu in dfPT['CMU Phonemes'][0:39]]/max(avGainRank.values)) 

#pd.concat([Jeffers,dfPT['CMU Phonemes'][0:39]],axis=1).set_index('CMU Phonemes')

# %% [markdown]
# Here it is! Use the drop down menu below to select the coloring scheme for the phonetic chart.

# %%
from IPython.html.widgets import interact
interact(update,f=titles)

# %%
BokehTable(cmaps)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0192660c-b8fb-42d1-a3b6-d5cfd935e64d">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="d6330add-27db-418e-a84e-1df058d383a0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6330add-27db-418e-a84e-1df058d383a0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6330add-27db-418e-a84e-1df058d383a0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3d672125-d5fb-4908-934e-3638aef58f6b":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"type_color"},"height":{"units":"data","value":0.9},"line_color":{"field":"type_color"},"width":{"units":"data","value":0.9},"x":{"field":"xaxis"},"y":{"field":"yaxis"}},"id":"60535344-fd8d-4799-91b6-5b76f9ecf2fe","type":"Rect"},{"attributes":{},"id":"d8c243df-fc90-4277-945f-7d2d775edc35","type":"BasicTicker"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"b8c24b53-da8e-42c7-a6ec-c0e69c833380","subtype":"Figure","type":"Plot"},"ticker":{"id":"d8c243df-fc90-4277-945f-7d2d775edc35","type":"BasicTicker"}},"id":"c9ef13c3-6e22-459a-ad64-edf65ce21eb3","type":"Grid"},{"attributes":{"below":[{"id":"0a385b7e-a7e4-4057-a17d-9576fcf24e4f","type":"LinearAxis"}],"left":[{"id":"0dcb455c-48de-4cb1-9ee9-eacce85b3796","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_width":1200,"renderers":[{"id":"0a385b7e-a7e4-4057-a17d-9576fcf24e4f","type":"LinearAxis"},{"id":"820517f6-975d-47de-98c3-6c6745895d6f","type":"Grid"},{"id":"0dcb455c-48de-4cb1-9ee9-eacce85b3796","type":"LinearAxis"},{"id":"47106768-3134-420f-a698-87e4aeed66d0","type":"Grid"},{"id":"976bad5f-6598-41ab-bb6b-c82882fc102d","type":"GlyphRenderer"},{"id":"950d6dda-14cc-416a-8e59-f50d7684ee65","type":"GlyphRenderer"}],"title":"Sumby Noisy Visibility Map","tool_events":{"id":"64a9e237-9ccf-4389-a0fc-f4982a5856d8","type":"ToolEvents"},"toolbar_location":null,"tools":[{"id":"b0828f6c-92c0-4a1f-a774-25af15c5b3c8","type":"ResizeTool"},{"id":"ecca96ac-2ffe-4094-86c0-20bbb169eaec","type":"HoverTool"},{"id":"40266165-beac-459e-a988-285ff9f1ddb9","type":"PreviewSaveTool"}],"x_range":{"id":"f93560ed-2ca9-4ec8-9be7-dd41450e0f50","type":"DataRange1d"},"y_range":{"id":"71efc6cb-9deb-425a-aea1-baf66a84fcf6","type":"DataRange1d"}},"id":"f93ecd76-898a-4440-ba84-34dbe8112219","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.9},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.9},"x":{"field":"xaxis"},"y":{"field":"yaxis"}},"id":"b9d26924-908c-4173-9173-bb0f349d164d","type":"Rect"},{"attributes":{},"id":"5b9c5dec-e0b2-47d2-b609-019559924769","type":"ToolEvents"},{"attributes":{},"id":"06c17690-950b-4fc6-945b-302dac63420e","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"3dcb3db6-064b-43ca-9ba0-7cd7ee9406b9","subtype":"Figure","type":"Plot"},"ticker":{"id":"b76364c3-a830-420d-a90f-e83935ac2deb","type":"BasicTicker"}},"id":"65b8f216-f87c-4fef-964e-ca125d8a66ad","type":"Grid"},{"attributes":{"text":{"field":"sym"},"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"15pt"},"text_font_style":"bold","x":{"field":"xaxis"},"y":{"field":"yaxis"}},"id":"eef7481c-26de-4035-8b07-690f779441d3","type":"Text"},{"attributes":{},"id":"9df2e2f9-3447-40d9-9f14-08096dda3951","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"64b8e424-ac40-4075-9e37-092c617b46d9","subtype":"Figure","type":"Plot"},"tooltips":[["cmu","@cmu"],["example","@example"],["jrank","@jrank"],["mpcrank","@mpcrank"],["gaorank","@gaorank"],["gvrank","@gvrank"]]},"id":"daee13e1-9f6a-407c-bb8c-1c515efaedef","type":"HoverTool"},{"attributes":{"text":{"field":"sym"},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"15pt"},"text_font_style":"bold","x":{"field":"xaxis"},"y":{"field":"yaxis"}},"id":"995dedb3-1da1-40da-aec9-0c4c263494c1","type":"Text"},{"attributes":{},"id":"0ba120cb-4d43-41eb-96ff-e5219a4a8f60","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"06c17690-950b-4fc6-945b-302dac63420e","type":"BasicTickFormatter"},"plot":{"id":"7f7f614d-14f7-4e3d-ba8f-a72a473e461b","subtype":"Figure","type":"Plot"},"ticker":{"id":"c0a6c091-0d24-4493-8664-d6bcc376cc51"," ...

# %%
#For future reference
#callback = CustomJS(args=dict(source=source), code="""
#        var data = source.get('data');
#        var f = cb_obj.get('value')
#        x = data['x']
#        y = data['y']
#        for (i = 0; i < x.length; i++) {
#            y[i] = Math.pow(x[i], f)
#        }
#        source.trigger('change');
#    """)

# %% [markdown]
# We can also look at the map for the clear data

# %%
data = df.loc[df['BabbleCond'] =='Clear',:]


data = data[['TargetPhoneme','PhonemeHitBool','VideoCond']].groupby(['TargetPhoneme','VideoCond']).mean()
data = data.unstack()
av = 1-data.xs('Audiovisual',level = 1,axis=1)
ao = 1-data.xs('Auditory Only',level = 1,axis=1)
sumbyRatio = (ao-av)/ao
sumbyRank = sumbyRatio.rank(ascending = False)
cmaps = []
titles = []
cmaps.append([sumbyRank.loc[sumbyRank.index == cmu].values[0][0] for cmu in dfPT['CMU Phonemes'][0:39]]/max(sumbyRank.values))
titles.append('Sumby Clear Visibility Map')
BokehTable(cmaps)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d6dee7d5-1d0f-44fc-bd1c-9c87540156cd">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="050b74c2-4999-4f04-9468-fda8b3fbe641"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("050b74c2-4999-4f04-9468-fda8b3fbe641");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '050b74c2-4999-4f04-9468-fda8b3fbe641' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"72564a4a-cb2f-4559-924e-5e188d7fe493":{"roots":{"references":[{"attributes":{"below":[{"id":"0a385b7e-a7e4-4057-a17d-9576fcf24e4f","type":"LinearAxis"}],"left":[{"id":"0dcb455c-48de-4cb1-9ee9-eacce85b3796","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_width":1200,"renderers":[{"id":"0a385b7e-a7e4-4057-a17d-9576fcf24e4f","type":"LinearAxis"},{"id":"820517f6-975d-47de-98c3-6c6745895d6f","type":"Grid"},{"id":"0dcb455c-48de-4cb1-9ee9-eacce85b3796","type":"LinearAxis"},{"id":"47106768-3134-420f-a698-87e4aeed66d0","type":"Grid"},{"id":"976bad5f-6598-41ab-bb6b-c82882fc102d","type":"GlyphRenderer"},{"id":"950d6dda-14cc-416a-8e59-f50d7684ee65","type":"GlyphRenderer"}],"title":"Sumby Noisy Visibility Map","tool_events":{"id":"64a9e237-9ccf-4389-a0fc-f4982a5856d8","type":"ToolEvents"},"toolbar_location":null,"tools":[{"id":"b0828f6c-92c0-4a1f-a774-25af15c5b3c8","type":"ResizeTool"},{"id":"ecca96ac-2ffe-4094-86c0-20bbb169eaec","type":"HoverTool"},{"id":"40266165-beac-459e-a988-285ff9f1ddb9","type":"PreviewSaveTool"}],"x_range":{"id":"f93560ed-2ca9-4ec8-9be7-dd41450e0f50","type":"DataRange1d"},"y_range":{"id":"71efc6cb-9deb-425a-aea1-baf66a84fcf6","type":"DataRange1d"}},"id":"f93ecd76-898a-4440-ba84-34dbe8112219","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"85ba5869-312f-434c-bd8a-863da1fef993","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.9},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.9},"x":{"field":"xaxis"},"y":{"field":"yaxis"}},"id":"7429cb39-fdb6-4241-a41c-83c93e36e2a3","type":"Rect"},{"attributes":{},"id":"0ba120cb-4d43-41eb-96ff-e5219a4a8f60","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bcd4b38c-66f5-49c5-a1b8-3aac8acc0b54","subtype":"Figure","type":"Plot"}},"id":"51c3dcde-2be1-473c-bf60-a28c9a630496","type":"ResizeTool"},{"attributes":{"callback":null},"id":"18434269-d0d4-4532-aa15-d78d1e2f06f6","type":"DataRange1d"},{"attributes":{},"id":"e171ef43-cd02-4b45-a5b6-2f870fffe0ad","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.9},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.9},"x":{"field":"xaxis"},"y":{"field":"yaxis"}},"id":"6d9ffb80-6d73-4f54-a214-7e06fc0a170e","type":"Rect"},{"attributes":{"callback":null,"column_names":["type_color","gaorank","yaxis","mpcrank","jrank","sym","xaxis","gvrank","cmu","type","example"],"data":{"cmu":["AA","AE","AH","AO","AW","AY","B","CH","D","DH","EH","ER","EY","F","G","HH","IH","IY","JH","K","L","M","N","NG","OW","OY","P","R","S","SH","T","TH","UH","UW","V","W","Y","Z","ZH","SIL"],"example":["odd","at","hut","ought","cow","hide","be","cheese","dee","thee","Ed","hurt","ate","fee","green","he","it","eat","gee","key","lee","me","knee","ping","oat","toy","pee","read","sea","she","tea","theta","hood","two","vee","we","yield","zee","seizure","silence"],"gaorank":[28.5,10.0,39.0,28.5,34.0,4.0,31.0,19.0,38.0,23.0,30.0,25.0,8.0,1.0,27.0,20.0,33.0,13.0,22.0,9.0,26.0,11.0,18.0,15.0,21.0,7.0,12.0,32.0,2.0,5.5,36.0,40.0,37.0,16.0,24.0,17.0,35.0,14.0,5.5,3.0],"gvrank":[8.5,20.0,6.0,8.5,1.0,28.0,10.0,39.0,19.0,26.0,14.0,16.0,25.0,22.0,34.0,33.0,17.0,27.0,35.0,37.0,18.0,7.0,23.0,40.0,4.0,21.0,11.0,24.0,30.0,31.5,13.0,38.0,36.0,15.0,2.0,3.0,12.0,29.0,31.5,5.0],"jrank":[9,9,9,7,4,9,3,6,10,5,9,2,9,1,11,12,9,9,6,11,10,3,10,11,2,7,3,2,8,6,10,5,2,2,1,2,9,8,6,12],"mpcrank":[11,11,11,6,2,11,3,8,10,4,11,5,11,1,9,8,11,11,8,9,10,3,10,9,5,6,3,5,7,8,10,4,5,5,1,5,11,7,8,8],"sym":["\u0251","\u00e6","\u028c","\u0254","a\u028a","a\u026a","b","t\u0283","d","\u00f0","\u025b","\u025a","e\u026a","f","g","h","\u026a","i\u02d0","d\u0292","k","l","m","n","\u014b","o\u028a","\u0254\u026a","p","\u0279","s","\u0283","t","\u03b8","\u028a","u\u02d0","v","w","j","z","\u0292","_"],"type":["0.75","0.75" ...

# %% [markdown]
# ### Did participants have similar SNR values across speakers and each other?

# %%
df['dBSNR']
